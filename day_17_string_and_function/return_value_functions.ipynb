# %% [markdown]
# ## function for adding two numbers

# %%
def add(n1,n2):

    result = n1+n2

    return result

add_result=add(100,200)
print(add_result)
# Out:
# Failed to restart the Kernel.
#
# Unable to start Kernel 'Python 3.14.2' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#create function for returning cube of a number
