# %%
print("hello")
# Out:
# hello

# %%
penguins = [
    {"id": 1, "species": "Adelie", "island": "Torgersen", "bill_length": 39.1, "bill_depth": 18.7, "flipper_length": 181, "body_mass": 3750, "sex": "Male"},
    {"id": 2, "species": "Adelie", "island": "Torgersen", "bill_length": 39.5, "bill_depth": 17.4, "flipper_length": 186, "body_mass": 3800, "sex": "Female"},
    {"id": 3, "species": "Adelie", "island": "Torgersen", "bill_length": 40.3, "bill_depth": 18.0, "flipper_length": 195, "body_mass": 3250, "sex": "Female"},
    {"id": 4, "species": "Adelie", "island": "Torgersen", "bill_length": 36.7, "bill_depth": 19.3, "flipper_length": 193, "body_mass": 3450, "sex": "Female"},
    {"id": 5, "species": "Adelie", "island": "Torgersen", "bill_length": 39.3, "bill_depth": 20.6, "flipper_length": 190, "body_mass": 3650, "sex": "Male"},
    {"id": 6, "species": "Adelie", "island": "Torgersen", "bill_length": 38.9, "bill_depth": 17.8, "flipper_length": 181, "body_mass": 3625, "sex": "Female"},
    {"id": 7, "species": "Adelie", "island": "Torgersen", "bill_length": 39.2, "bill_depth": 19.6, "flipper_length": 195, "body_mass": 4675, "sex": "Male"},
    {"id": 8, "species": "Adelie", "island": "Torgersen", "bill_length": 41.1, "bill_depth": 17.6, "flipper_length": 182, "body_mass": 3200, "sex": "Female"},
    {"id": 9, "species": "Adelie", "island": "Torgersen", "bill_length": 38.6, "bill_depth": 21.2, "flipper_length": 191, "body_mass": 3800, "sex": "Male"},
    {"id": 10, "species": "Adelie", "island": "Torgersen", "bill_length": 34.6, "bill_depth": 21.1, "flipper_length": 198, "body_mass": 4400, "sex": "Male"},

    {"id": 11, "species": "Adelie", "island": "Biscoe", "bill_length": 37.8, "bill_depth": 18.3, "flipper_length": 174, "body_mass": 3400, "sex": "Female"},
    {"id": 12, "species": "Adelie", "island": "Biscoe", "bill_length": 37.7, "bill_depth": 18.7, "flipper_length": 180, "body_mass": 3600, "sex": "Male"},
    {"id": 13, "species": "Adelie", "island": "Biscoe", "bill_length": 35.9, "bill_depth": 19.2, "flipper_length": 189, "body_mass": 3800, "sex": "Female"},
    {"id": 14, "species": "Adelie", "island": "Biscoe", "bill_length": 38.2, "bill_depth": 18.1, "flipper_length": 185, "body_mass": 3950, "sex": "Male"},
    {"id": 15, "species": "Adelie", "island": "Biscoe", "bill_length": 38.8, "bill_depth": 17.2, "flipper_length": 180, "body_mass": 3800, "sex": "Female"},
    {"id": 16, "species": "Adelie", "island": "Biscoe", "bill_length": 35.3, "bill_depth": 18.9, "flipper_length": 187, "body_mass": 3800, "sex": "Female"},
    {"id": 17, "species": "Adelie", "island": "Biscoe", "bill_length": 40.6, "bill_depth": 18.6, "flipper_length": 183, "body_mass": 3550, "sex": "Male"},
    {"id": 18, "species": "Adelie", "island": "Biscoe", "bill_length": 36.5, "bill_depth": 18.0, "flipper_length": 182, "body_mass": 3150, "sex": "Female"},

    {"id": 19, "species": "Chinstrap", "island": "Dream", "bill_length": 46.5, "bill_depth": 17.9, "flipper_length": 192, "body_mass": 3500, "sex": "Female"},
    {"id": 20, "species": "Chinstrap", "island": "Dream", "bill_length": 50.0, "bill_depth": 19.5, "flipper_length": 196, "body_mass": 3900, "sex": "Male"},
    {"id": 21, "species": "Chinstrap", "island": "Dream", "bill_length": 51.3, "bill_depth": 19.2, "flipper_length": 193, "body_mass": 3650, "sex": "Male"},
    {"id": 22, "species": "Chinstrap", "island": "Dream", "bill_length": 45.4, "bill_depth": 18.7, "flipper_length": 188, "body_mass": 3525, "sex": "Female"},
    {"id": 23, "species": "Chinstrap", "island": "Dream", "bill_length": 52.7, "bill_depth": 19.8, "flipper_length": 197, "body_mass": 3725, "sex": "Male"},
    {"id": 24, "species": "Chinstrap", "island": "Dream", "bill_length": 45.2, "bill_depth": 17.8, "flipper_length": 198, "body_mass": 3950, "sex": "Female"},
    {"id": 25, "species": "Chinstrap", "island": "Dream", "bill_length": 46.1, "bill_depth": 18.2, "flipper_length": 178, "body_mass": 3250, "sex": "Female"},
    {"id": 26, "species": "Chinstrap", "island": "Dream", "bill_length": 51.3, "bill_depth": 18.2, "flipper_length": 197, "body_mass": 3775, "sex": "Male"},
    {"id": 27, "species": "Chinstrap", "island": "Dream", "bill_length": 46.0, "bill_depth": 18.9, "flipper_length": 195, "body_mass": 4150, "sex": "Male"},
    {"id": 28, "species": "Chinstrap", "island": "Dream", "bill_length": 51.3, "bill_depth": 19.9, "flipper_length": 198, "body_mass": 3700, "sex": "Male"},

    {"id": 29, "species": "Gentoo", "island": "Biscoe", "bill_length": 46.1, "bill_depth": 13.2, "flipper_length": 211, "body_mass": 4500, "sex": "Female"},
    {"id": 30, "species": "Gentoo", "island": "Biscoe", "bill_length": 50.0, "bill_depth": 16.3, "flipper_length": 230, "body_mass": 5700, "sex": "Male"},
    {"id": 31, "species": "Gentoo", "island": "Biscoe", "bill_length": 48.7, "bill_depth": 14.1, "flipper_length": 210, "body_mass": 4450, "sex": "Female"},
    {"id": 32, "species": "Gentoo", "island": "Biscoe", "bill_length": 50.0, "bill_depth": 15.2, "flipper_length": 218, "body_mass": 5700, "sex": "Male"},
    {"id": 33, "species": "Gentoo", "island": "Biscoe", "bill_length": 47.6, "bill_depth": 14.5, "flipper_length": 215, "body_mass": 5400, "sex": "Male"},
    {"id": 34, "species": "Gentoo", "island": "Biscoe", "bill_length": 46.5, "bill_depth": 13.5, "flipper_length": 210, "body_mass": 4550, "sex": "Female"},
    {"id": 35, "species": "Gentoo", "island": "Biscoe", "bill_length": 45.4, "bill_depth": 14.6, "flipper_length": 211, "body_mass": 4800, "sex": "Female"},
    {"id": 36, "species": "Gentoo", "island": "Biscoe", "bill_length": 46.7, "bill_depth": 15.3, "flipper_length": 219, "body_mass": 5200, "sex": "Male"},
    {"id": 37, "species": "Gentoo", "island": "Biscoe", "bill_length": 43.3, "bill_depth": 13.4, "flipper_length": 209, "body_mass": 4400, "sex": "Female"},
    {"id": 38, "species": "Gentoo", "island": "Biscoe", "bill_length": 46.8, "bill_depth": 15.4, "flipper_length": 215, "body_mass": 5150, "sex": "Male"},

    {"id": 39, "species": "Adelie", "island": "Dream", "bill_length": 39.8, "bill_depth": 19.1, "flipper_length": 184, "body_mass": 4650, "sex": "Male"},
    {"id": 40, "species": "Adelie", "island": "Dream", "bill_length": 36.0, "bill_depth": 18.5, "flipper_length": 186, "body_mass": 3100, "sex": "Female"},
    {"id": 41, "species": "Adelie", "island": "Dream", "bill_length": 37.9, "bill_depth": 18.6, "flipper_length": 172, "body_mass": 3150, "sex": "Female"},
    {"id": 42, "species": "Chinstrap", "island": "Dream", "bill_length": 49.5, "bill_depth": 19.0, "flipper_length": 200, "body_mass": 3800, "sex": "Male"},
    {"id": 43, "species": "Chinstrap", "island": "Dream", "bill_length": 48.2, "bill_depth": 18.1, "flipper_length": 202, "body_mass": 4050, "sex": "Male"},
    {"id": 44, "species": "Chinstrap", "island": "Dream", "bill_length": 45.7, "bill_depth": 17.3, "flipper_length": 193, "body_mass": 3600, "sex": "Female"},
    {"id": 45, "species": "Gentoo", "island": "Biscoe", "bill_length": 49.0, "bill_depth": 15.2, "flipper_length": 221, "body_mass": 5500, "sex": "Male"},
    {"id": 46, "species": "Gentoo", "island": "Biscoe", "bill_length": 44.4, "bill_depth": 17.3, "flipper_length": 219, "body_mass": 5250, "sex": "Male"},
    {"id": 47, "species": "Gentoo", "island": "Biscoe", "bill_length": 48.4, "bill_depth": 14.4, "flipper_length": 203, "body_mass": 4625, "sex": "Female"},
    {"id": 48, "species": "Gentoo", "island": "Biscoe", "bill_length": 45.8, "bill_depth": 14.6, "flipper_length": 219, "body_mass": 4700, "sex": "Female"},
    {"id": 49, "species": "Gentoo", "island": "Biscoe", "bill_length": 49.2, "bill_depth": 15.2, "flipper_length": 221, "body_mass": 6300, "sex": "Male"},
    {"id": 50, "species": "Gentoo", "island": "Biscoe", "bill_length": 46.2, "bill_depth": 14.5, "flipper_length": 209, "body_mass": 4800, "sex": "Female"}
]

# %% [markdown]
# Print the names/species of all 50 penguins.
# Find the total number of penguins in the dataset.
# Find all penguins belonging to the Adelie species.
# Find all penguins from the Biscoe island.
# Find all male penguins.
# Find all penguins whose body mass is greater than 5000 g.
# Find the penguin with the highest body mass.
# Find the penguin with the smallest body mass.
# Calculate the average body mass of all penguins.
# Calculate the average bill length of Adelie penguins.
# Find all penguins whose flipper length is greater than 200 mm.
# Count how many penguins belong to each species.
# Count how many penguins belong to each island.
# Find the average body mass for each species.
# Find all female Gentoo penguins.
# Find the heaviest male penguin.
# Sort all penguins by body mass in ascending order.
# Sort all penguins by bill length in descending order.
# Find penguins whose bill length is between 40 and 50 mm.
# Find the species having the highest average flipper length.

# %%
#all species

all_species = {di.get("species") for di in penguins}

print(all_species)
# Out:
# {'Adelie', 'Chinstrap', 'Gentoo'}

# %%
all_islands = {di.get("island") for di in penguins}

print(all_islands)
# Out:
# {'Torgersen', 'Dream', 'Biscoe'}

# %%
gento_species= [di for di in penguins if di.get("species")=="Gentoo"]

print(gento_species)
# Out:
# [{'id': 29, 'species': 'Gentoo', 'island': 'Biscoe', 'bill_length': 46.1, 'bill_depth': 13.2, 'flipper_length': 211, 'body_mass': 4500, 'sex': 'Female'}, {'id': 30, 'species': 'Gentoo', 'island': 'Biscoe', 'bill_length': 50.0, 'bill_depth': 16.3, 'flipper_length': 230, 'body_mass': 5700, 'sex': 'Male'}, {'id': 31, 'species': 'Gentoo', 'island': 'Biscoe', 'bill_length': 48.7, 'bill_depth': 14.1, 'flipper_length': 210, 'body_mass': 4450, 'sex': 'Female'}, {'id': 32, 'species': 'Gentoo', 'island': 'Biscoe', 'bill_length': 50.0, 'bill_depth': 15.2, 'flipper_length': 218, 'body_mass': 5700, 'sex': 'Male'}, {'id': 33, 'species': 'Gentoo', 'island': 'Biscoe', 'bill_length': 47.6, 'bill_depth': 14.5, 'flipper_length': 215, 'body_mass': 5400, 'sex': 'Male'}, {'id': 34, 'species': 'Gentoo', 'island': 'Biscoe', 'bill_length': 46.5, 'bill_depth': 13.5, 'flipper_length': 210, 'body_mass': 4550, 'sex': 'Female'}, {'id': 35, 'species': 'Gentoo', 'island': 'Biscoe', 'bill_length': 45.4, 'bill_depth'
# ...

# %%
#biil_length > 50 penguins

bill_length_filter = [di for di in penguins if di.get("bill_length")>50]

print(bill_length_filter)
# Out:
# [{'id': 21, 'species': 'Chinstrap', 'island': 'Dream', 'bill_length': 51.3, 'bill_depth': 19.2, 'flipper_length': 193, 'body_mass': 3650, 'sex': 'Male'}, {'id': 23, 'species': 'Chinstrap', 'island': 'Dream', 'bill_length': 52.7, 'bill_depth': 19.8, 'flipper_length': 197, 'body_mass': 3725, 'sex': 'Male'}, {'id': 26, 'species': 'Chinstrap', 'island': 'Dream', 'bill_length': 51.3, 'bill_depth': 18.2, 'flipper_length': 197, 'body_mass': 3775, 'sex': 'Male'}, {'id': 28, 'species': 'Chinstrap', 'island': 'Dream', 'bill_length': 51.3, 'bill_depth': 19.9, 'flipper_length': 198, 'body_mass': 3700, 'sex': 'Male'}]

# %%
#species summary

speciels_list = [di.get("species") for di in penguins]

species_count = {s:speciels_list.count(s) for s in speciels_list}

species_count
# Out:
# {'Adelie': 21, 'Chinstrap': 13, 'Gentoo': 16}

# %%
all_islands = [di.get("island") for di in penguins ]

island_count = {i:all_islands.count(i) for i in all_islands}

island_count
# Out:
# {'Torgersen': 10, 'Biscoe': 24, 'Dream': 16}

# %%
#highest bill_length

all_bill_length = [di.get("bill_length") for di in penguins]

max_bill_length = max(all_bill_length)


max_bill_length_penguin = [di  for di in penguins if di.get("bill_length")==max_bill_length]

print(max_bill_length_penguin)
# Out:
# {'id': 23, 'species': 'Chinstrap', 'island': 'Dream', 'bill_length': 52.7, 'bill_depth': 19.8, 'flipper_length': 197, 'body_mass': 3725, 'sex': 'Male'}

# %%
#lambda function : anonymous function with single expression

add= lambda n1,n2:n1+n2
print(add(100,200))

sub=lambda n1,n2:n1-n2
print(sub(10,2))

cube=lambda n:n**3
print(cube(3))

max_two=lambda n1,n2:n1 if n1>n2 else n2
print(max_two(10,20))

min_two = lambda n1,n2:n1 if n1<n2 else n2
print(min_two(10,1))
# Out:
# 300
# 8
# 27
# 20
# 1

# %%
#hig

print(max(penguins,key=lambda di:di.get("bill_length")))
# Out:
# {'id': 23, 'species': 'Chinstrap', 'island': 'Dream', 'bill_length': 52.7, 'bill_depth': 19.8, 'flipper_length': 197, 'body_mass': 3725, 'sex': 'Male'}

# %%
#lowest

print(min(penguins,key=lambda di:di.get("bill_length")))
# Out:
# {'id': 10, 'species': 'Adelie', 'island': 'Torgersen', 'bill_length': 34.6, 'bill_depth': 21.1, 'flipper_length': 198, 'body_mass': 4400, 'sex': 'Male'}

# %%
#highest_bod_mass_penguine

print(max(penguins,key=lambda di:di.get("body_mass")))
# Out:
# {'id': 49, 'species': 'Gentoo', 'island': 'Biscoe', 'bill_length': 49.2, 'bill_depth': 15.2, 'flipper_length': 221, 'body_mass': 6300, 'sex': 'Male'}

# %%
#body_mass_sum wrt species

species_body_mass_sum={}

for di in penguins:

    species = di.get("species")

    body_mass = di.get("body_mass")

    if species in species_body_mass_sum:

        species_body_mass_sum[species]+=body_mass

    else:

        species_body_mass_sum[species]=body_mass

print(species_body_mass_sum)
# Out:
# {'Adelie': 77550, 'Chinstrap': 48575, 'Gentoo': 81025}

# %%
orders=[
    {"id":1,"item":"tea","qty":4},
    {"id":2,"item":"tea","qty":2},
    {"id":3,"item":"cofee","qty":3},
    {"id":4,"item":"cofee","qty":2},
    {"id":5,"item":"dosa","qty":3},
    {"id":6,"item":"dosa","qty":2},
]

order_count={}

for di in orders:

    item = di.get("item")

    qty = di.get("qty")

    if item in order_count:

        order_count[item]+=qty

    else:

        order_count[item]=qty

print(order_count)
# Out:
# {'tea': 6, 'cofee': 5, 'dosa': 5}
